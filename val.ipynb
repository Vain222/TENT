# %%
# data/cifar10c/gaussian_noise.npy
import numpy as np
data = np.load('data/cifar10c/gaussian_noise.npy')
print(data.shape)  # (10000, 32, 32, 3)
# Out:
# (50000, 32, 32, 3)

# %%
# data[0] is [32, 32, 3] plot it
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(1, 1))
# i = 0
plt.imshow(data[i].astype(np.uint8))
i += 1
